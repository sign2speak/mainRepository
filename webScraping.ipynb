# %% [markdown]
# <a href="https://colab.research.google.com/github/sign2speak/mainRepository/blob/main/webScraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install playwright beautifulsoup4 requests
# !playwright install chromium
# Out:
# Requirement already satisfied: playwright in /usr/local/lib/python3.12/dist-packages (1.57.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.14.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.5)
# Requirement already satisfied: pyee<14,>=13 in /usr/local/lib/python3.12/dist-packages (from playwright) (13.0.0)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in /usr/local/lib/python3.12/dist-packages (from playwright) (3.3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.1.4)

# %%
# !apt-get update -qq
# !apt-get install -y \
  libatk-bridge2.0-0 \
  libatk1.0-0 \
  libcups2 \
  libdrm2 \
  libxkbcommon0 \
  libxcomposite1 \
  libxdamage1 \
  libxrandr2 \
  libgbm1 \
  libasound2
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libasound2 is already the newest version (1.2.6.1-1ubuntu1).
# libasound2 set to manually installed.
# libxdamage1 is already the newest version (1:1.1.5-2build2).
# libxdamage1 set to manually installed.
# libxkbcommon0 is already the newest version (1.4.0-1).
# libxkbcommon0 set to manually installed.
# libxrandr2 is already the newest version (2:1.5.2-1build1).
# libxrandr2 set to manually installed.
# libcups2 is already the newest version (2.4.1op1-1ubuntu4.16).
# libcups2 set to manually installed.
# libdrm2 is already the newest version (2.4.113-2~ubuntu0.22.04.1).
# libdrm2 set to manually installed.
# libgbm1 is already the newest version (23.2.1-1ubuntu3.1~22.04.3).
# libgbm1 set to manually installed.
# The following additional packages will be installed:
#   at-spi2-core gsettings-desktop-schemas libatk1.0-data libatspi2.0-0 libxtst6
#   session-migration
# The following NEW packages will be installed:
#   at-spi2-core gsettings-desktop-schemas libatk-bridge2.0-0 libatk1.0-0
#   libatk1.0-data libatspi2.0-0 libxcomposite1 libxtst6 session-migration
# 0 upgraded, 9 newly installed, 0 to remove and 94 not upgraded.
# Need to get 318 kB of archives.
# After this operation, 1,497 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatspi2.0-0 amd64 2.44.0-3 [80.9 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 session-migration amd64 0.3.6 [9,774 B]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 gsettings-desktop-schemas all 42.0-1ubuntu1 [31.1 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 at-spi2-core amd64 2.44.0-3 [54.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-data all 2.36.0-3build1 [2,824 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-0 amd64 2.36.0-3build1 [51.9 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-bridge2.0-0 amd64 2.38.0-3 [66.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcomposite1 amd64 1:0.4.5-1build2 [7,192 B]
# Fetched 318 kB in 1s (248 kB/s)
# Selecting previously unselected package libatspi2.0-0:amd64.
# (Reading database ... 122152 files and directories currently installed.)
# Preparing to unpack .../0-libatspi2.0-0_2.44.0-3_amd64.deb ...
# Unpacking libatspi2.0-0:amd64 (2.44.0-3) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../1-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package session-migration.
# Preparing to unpack .../2-session-migration_0.3.6_amd64.deb ...
# Unpacking session-migration (0.3.6) ...
# Selecting previously unselected package gsettings-desktop-schemas.
# Preparing to unpack .../3-gsettings-desktop-schemas_42.0-1ubuntu1_all.deb ...
# Unpacking gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Selecting previously unselected package at-spi2-core.
# Preparing to unpack .../4-at-spi2-core_2.44.0-3_amd64.deb ...
# Unpacking at-spi2-core (2.44.0-3) ...
# Selecting previously unselected package libatk1.0-data.
# Preparing to unpack .../5-libatk1.0-data_2.36.0-3build1_all.deb ...
# Unpacking libatk1.0-data (2.36.0-3build1) ...
# Selecting previously unselected package libatk1.0-0:amd64.
# Preparing to unpack .../6-libatk1.0-0_2.36.0-3build1_amd64.deb ...
# Unpacking libatk1.0-0:amd64 (2.36.0-3build1) ...
# Selecting previously unselected package libatk-bridge2.0-0:amd64.
# Preparing to unpack .../7-libatk-bridge2.0-0_2.38.0-3_amd64.deb ...
# Unpacking libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Selecting previously unselected package libxcomposite1:amd64.
# Preparing to unpack .../8-libxcomposite1_1%3a0.4.5-1build2_amd64.deb ...
# Unpacking libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Setting up session-migration (0.3.6) ...
# Created symlink /etc/systemd/user/graphical-session-pre.target.wants/session-migration.service → /usr/lib/systemd/user/session-migration.service.
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libatspi2.0-0:amd64 (2.44.0-3) ...
# Setting up libatk1.0-data (2.36.0-3build1) ...
# Setting up libatk1.0-0:amd64 (2.36.0-3build1) ...
# Setting up libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Setting up gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Setting up libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Processing triggers for libglib2.0-0:amd64 (2.72.4-0ubuntu2.6) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Setting up at-spi2-core (2.44.0-3) ...

# %%
# !playwright install chromium

# %%
import os
import re
import time
import asyncio
import requests
from urllib.parse import urlparse
from bs4 import BeautifulSoup
from playwright.async_api import async_playwright

# =========================
# CONFIG
# =========================
BASE_URL = "https://psl.org.pk"
CATEGORY_URL = "https://psl.org.pk/dictionary/65-sentences"
SAVE_DIR = "/content/PSL_VIDEOS"

HEADERS = {"User-Agent": "Mozilla/5.0"}
os.makedirs(SAVE_DIR, exist_ok=True)

# =========================
# UTILS
# =========================
def clean_filename(text: str) -> str:
    text = text.lower()
    text = re.sub(r"[^\w\s]", "", text)
    text = re.sub(r"\s+", "_", text)
    return text.strip("_")

def filename_from_detail_url(detail_url: str) -> str:
    """
    https://psl.org.pk/dictionary/65-sentences/4265-are-you-deaf?_rsc=abc
    -> are_you_deaf.mp4
    """
    path = urlparse(detail_url).path
    last = path.rstrip("/").split("/")[-1]      # 4265-are-you-deaf
    last = re.sub(r"^\d+-", "", last)           # remove numeric id
    last = last.replace("-", "_")               # hyphens -> underscores
    last = clean_filename(last)
    return f"{last}.mp4"

# =========================
# MAIN ASYNC PIPELINE
# =========================
async def main():
    print("🚀 Launching Playwright (async)")

    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        # -------------------------
        # STEP 1: COLLECT DETAIL LINKS
        # -------------------------
        print("📄 Loading category page…")
        await page.goto(CATEGORY_URL, timeout=60000)
        await page.wait_for_timeout(8000)  # wait for JS cards

        anchors = await page.query_selector_all("a")
        links = set()

        for a in anchors:
            href = await a.get_attribute("href")
            if href and "/dictionary/65-sentences/" in href:
                if href.startswith("/"):
                    href = BASE_URL + href
                links.add(href)

        print(f"✅ Found {len(links)} dictionary entries")

        # -------------------------
        # STEP 2: PROCESS EACH DETAIL PAGE
        # -------------------------
        for idx, detail_url in enumerate(sorted(links), start=1):
            print(f"\n[{idx}/{len(links)}] Processing: {detail_url}")

            try:
                await page.goto(detail_url, timeout=60000)
                await page.wait_for_timeout(4000)  # wait for video hydration

                html = await page.content()
                soup = BeautifulSoup(html, "html.parser")

                filename = filename_from_detail_url(detail_url)
                save_path = os.path.join(SAVE_DIR, filename)

                if os.path.exists(save_path):
                    print("  ⏭️ Already exists:", filename)
                    continue

                # Extract JS-injected video source
                source = soup.find("source", src=True)
                if not source:
                    print("  ❌ No video source found")
                    continue

                video_url = source["src"]
                print("  ⬇️ Downloading:", filename)

                r = requests.get(video_url, stream=True, headers=HEADERS)
                with open(save_path, "wb") as f:
                    for chunk in r.iter_content(8192):
                        if chunk:
                            f.write(chunk)

                print("  ✅ Saved:", filename)
                time.sleep(0.4)

            except Exception as e:
                print("  ❌ Error:", e)

        await browser.close()

    print("\n🎉 ALL VIDEOS DOWNLOADED SUCCESSFULLY")

# =========================
# RUN (Colab-safe)
# =========================
await main()
# Out:
# 🚀 Launching Playwright (async)
# 📄 Loading category page…
# ✅ Found 221 dictionary entries
#
# [1/221] Processing: https://psl.org.pk/dictionary/65-sentences/4265-are-you-deaf
#   ⬇️ Downloading: are_you_deaf.mp4
#   ✅ Saved: are_you_deaf.mp4
#
# [2/221] Processing: https://psl.org.pk/dictionary/65-sentences/4266-are-you-hungry
#   ⬇️ Downloading: are_you_hungry.mp4
#   ✅ Saved: are_you_hungry.mp4
#
# [3/221] Processing: https://psl.org.pk/dictionary/65-sentences/4267-are-you-ready
#   ⬇️ Downloading: are_you_ready.mp4
#   ✅ Saved: are_you_ready.mp4
#
# [4/221] Processing: https://psl.org.pk/dictionary/65-sentences/4268-assalam-o-alaikum
#   ⬇️ Downloading: assalam_o_alaikum.mp4
#   ✅ Saved: assalam_o_alaikum.mp4
#
# [5/221] Processing: https://psl.org.pk/dictionary/65-sentences/4269-beware
#   ⬇️ Downloading: beware.mp4
#   ✅ Saved: beware.mp4
#
# [6/221] Processing: https://psl.org.pk/dictionary/65-sentences/4270-call-the-ambulance
#   ⬇️ Downloading: call_the_ambulance.mp4
#   ✅ Saved: call_the_ambulance.mp4
#
# [7/221] Processing: https://psl.org.pk/dictionary/65-sentences/4271-can-i-help-you
#   ⬇️ Downloading: can_i_help_you.mp4
#   ✅ Saved: can_i_help_you.mp4
#
# [8/221] Processing: https://psl.org.pk/dictionary/65-sentences/4272-can-i-take-your-order
#   ⬇️ Downloading: can_i_take_your_order.mp4
#   ✅ Saved: can_i_take_your_order.mp4
#
# [9/221] Processing: https://psl.org.pk/dictionary/65-sentences/4273-can-i-use-the-toilet
#   ⬇️ Downloading: can_i_use_the_toilet.mp4
#   ✅ Saved: can_i_use_the_toilet.mp4
#
# [10/221] Processing: https://psl.org.pk/dictionary/65-sentences/4274-close-the-door
#   ⬇️ Downloading: close_the_door.mp4
#   ✅ Saved: close_the_door.mp4
#
# [11/221] Processing: https://psl.org.pk/dictionary/65-sentences/4275-close-the-window
#   ⬇️ Downloading: close_the_window.mp4
#   ✅ Saved: close_the_window.mp4
#
# [12/221] Processing: https://psl.org.pk/dictionary/65-sentences/4276-come-here!
#   ⬇️ Downloading: come_here.mp4
#   ✅ Saved: come_here.mp4
#
#   ⬇️ Downloading: i_went_to_a_school_for_hearing_children.mp4
#   ✅ Saved: i_went_to_a_school_for_hearing_children.mp4
#
# [79/221] Processing: https://psl.org.pk/dictionary/65-sentences/4343-i-will-be-back-soon
#   ⬇️ Downloading: i_will_be_back_soon.mp4
#   ✅ Saved: i_will_be_back_soon.mp4
#
# [80/221] Processing: https://psl.org.pk/dictionary/65-sentences/4344-i-would-like-to-interview-for-this-job
#   ⬇️ Downloading: i_would_like_to_interview_for_this_job.mp4
#   ✅ Saved: i_would_like_to_interview_for_this_job.mp4
#
# [81/221] Processing: https://psl.org.pk/dictionary/65-sentences/4345-i-ll-see-you-later
#   ⬇️ Downloading: i_ll_see_you_later.mp4
#   ✅ Saved: i_ll_see_you_later.mp4
#
# [82/221] Processing: https://psl.org.pk/dictionary/65-sentences/4346-is-it-broken
#   ⬇️ Downloading: is_it_broken.mp4
#   ✅ Saved: is_it_broken.mp4
#
# [83/221] Processing: https://psl.org.pk/dictionary/65-sentences/4347-is-it-far-from-here
#   ⬇️ Downloading: is_it_far_from_here.mp4
#   ✅ Saved: is_it_far_from_here.mp4
#
# [84/221] Processing: https://psl.org.pk/dictionary/65-sentences/4348-is-it-true
#   ⬇️ Downloading: is_it_true.mp4
#   ✅ Saved: is_it_true.mp4
#
# [85/221] Processing: https://psl.org.pk/dictionary/65-sentences/4349-is-somebody-meeting-you
#   ⬇️ Downloading: is_somebody_meeting_you.mp4
#   ✅ Saved: is_somebody_meeting_you.mp4
#
# [86/221] Processing: https://psl.org.pk/dictionary/65-sentences/4350-is-that-enough-for-you
#   ⬇️ Downloading: is_that_enough_for_you.mp4
#   ✅ Saved: is_that_enough_for_you.mp4
#
# [87/221] Processing: https://psl.org.pk/dictionary/65-sentences/4351-it-was-cold-this-morning
#   ⬇️ Downloading: it_was_cold_this_morning.mp4
#   ✅ Saved: it_was_cold_this_morning.mp4
#
# [88/221] Processing: https://psl.org.pk/dictionary/65-sentences/4352-let-s-go-to-a-restaurant
#   ⬇️ Downloading: let_s_go_to_a_restaurant.mp4
#   ✅ Saved: let_s_go_to_a_restaurant.mp4
#
# [89/221] Processing: https://psl.org.pk/dictionary/65-sentences/4353-math-is-a-difficult-subject-for-me
#   ⬇️ Downloading: math_is_a_difficult_subject_for_me.mp4
#   ✅ Saved: math_is_a_difficult_subject_for_me.mp4
#
# [90/221] Processing: https://psl.org.pk/dictionary/65-sentences/4354-may-i-have-your-business-card
#   ⬇️ Downloading: may_i_have_your_business_card.mp4
#   ✅ Saved: may_i_have_your_business_card.mp4
#
# [91/221] Processing: https://psl.org.pk/dictionary/65-sentences/4355-maybe
#   ⬇️ Downloading: maybe.mp4
#   ✅ Saved: maybe.mp4
#
# [92/221] Processing: https://psl.org.pk/dictionary/65-sentences/4356-maybe-it-will-rain-tomorrow
#   ⬇️ Downloading: maybe_it_will_rain_tomorrow.mp4
#   ✅ Saved: maybe_it_will_rain_tomorrow.mp4
#
# [93/221] Processing: https://psl.org.pk/dictionary/65-sentences/4357-my-brother-is-younger-than-me
#   ✅ Saved: the_garbage_truck_comes_once_a_week.mp4
#
# [109/221] Processing: https://psl.org.pk/dictionary/65-sentences/4374-the-police-station-is-two-blocks-away.
#   ⬇️ Downloading: the_police_station_is_two_blocks_away.mp4
#   ✅ Saved: the_police_station_is_two_blocks_away.mp4
#
# [110/221] Processing: https://psl.org.pk/dictionary/65-sentences/4375-the-teacher-asked-me-a-lot-of-questions.
#   ⬇️ Downloading: the_teacher_asked_me_a_lot_of_questions.mp4
#   ✅ Saved: the_teacher_asked_me_a_lot_of_questions.mp4
#
# [111/221] Processing: https://psl.org.pk/dictionary/65-sentences/4376-there-has-been-an-accident
#   ⬇️ Downloading: there_has_been_an_accident.mp4
#   ✅ Saved: there_has_been_an_accident.mp4
#
# [112/221] Processing: https://psl.org.pk/dictionary/65-sentences/4377-there-is-no-sign-for-that-you-have-to-fingerspell-it.
#   ⬇️ Downloading: there_is_no_sign_for_that_you_have_to_fingerspell_it.mp4
#   ✅ Saved: there_is_no_sign_for_that_you_have_to_fingerspell_it.mp4
#
# [113/221] Processing: https://psl.org.pk/dictionary/65-sentences/4378-this-is-very-important.
#   ⬇️ Downloading: this_is_very_important.mp4
#   ✅ Saved: this_is_very_important.mp4
#
# [114/221] Processing: https://psl.org.pk/dictionary/65-sentences/4379-walaikum-as-salaam
#   ⬇️ Downloading: walaikum_as_salaam.mp4
#   ✅ Saved: walaikum_as_salaam.mp4
#
# [115/221] Processing: https://psl.org.pk/dictionary/65-sentences/4380-welcome
#   ⬇️ Downloading: welcome.mp4
#   ✅ Saved: welcome.mp4
#
# [116/221] Processing: https://psl.org.pk/dictionary/65-sentences/4381-well-done!
#   ⬇️ Downloading: well_done.mp4
#   ✅ Saved: well_done.mp4
#
# [117/221] Processing: https://psl.org.pk/dictionary/65-sentences/4382-what-for
#   ⬇️ Downloading: what_for.mp4
#   ✅ Saved: what_for.mp4
#
# [118/221] Processing: https://psl.org.pk/dictionary/65-sentences/4383-what-is-your-email-address
#   ⬇️ Downloading: what_is_your_email_address.mp4
#   ✅ Saved: what_is_your_email_address.mp4
#
# [119/221] Processing: https://psl.org.pk/dictionary/65-sentences/4384-what-is-your-name
#   ⬇️ Downloading: what_is_your_name.mp4
#   ✅ Saved: what_is_your_name.mp4
#
# [120/221] Processing: https://psl.org.pk/dictionary/65-sentences/4385-what-is-your-telephone-number
#   ⬇️ Downloading: what_is_your_telephone_number.mp4
#   ✅ Saved: what_is_your_telephone_number.mp4
#
# [121/221] Processing: https://psl.org.pk/dictionary/65-sentences/4386-what
#   ⬇️ Downloading: what.mp4
#   ✅ Saved: what.mp4
#
# [122/221] Processing: https://psl.org.pk/dictionary/65-sentences/4387-when
#   ⬇️ Downloading: when.mp4
#   ✅ Saved: when.mp4
#
# [123/221] Processing: https://psl.org.pk/dictionary/65-sentences/4388-where-do-you-live
#   ⬇️ Downloading: where_do_you_live.mp4
#   ✅ Saved: where_do_you_live.mp4
#
# [124/221] Processing: https://psl.org.pk/dictionary/65-sentences/4389-where
#   ⬇️ Downloading: where.mp4
#   ✅ Saved: where.mp4
#
# [125/221] Processing: https://psl.org.pk/dictionary/65-sentences/4390-which
#   ⬇️ Downloading: which.mp4
#   ✅ Saved: which.mp4
#
# [126/221] Processing: https://psl.org.pk/dictionary/65-sentences/4391-who
#   ⬇️ Downloading: who.mp4
#   ✅ Saved: who.mp4
#
# [127/221] Processing: https://psl.org.pk/dictionary/65-sentences/4392-whose
#   ⬇️ Downloading: whose.mp4
#   ✅ Saved: whose.mp4
#
# [128/221] Processing: https://psl.org.pk/dictionary/65-sentences/4393-why
#   ⬇️ Downloading: why.mp4
#   ✅ Saved: why.mp4
#
# [129/221] Processing: https://psl.org.pk/dictionary/65-sentences/4394-with-whom
#   ⬇️ Downloading: with_whom.mp4
#   ✅ Saved: with_whom.mp4
#
# [130/221] Processing: https://psl.org.pk/dictionary/65-sentences/4395-wow-excitement
#   ⬇️ Downloading: wow_excitement.mp4
#   ✅ Saved: wow_excitement.mp4
#
# [131/221] Processing: https://psl.org.pk/dictionary/65-sentences/4396-yes
#   ⬇️ Downloading: yes.mp4
#   ✅ Saved: yes.mp4
#
# [132/221] Processing: https://psl.org.pk/dictionary/65-sentences/7054-i-am-sick
#   ⬇️ Downloading: i_am_sick.mp4
#   ✅ Saved: i_am_sick.mp4
#
# [133/221] Processing: https://psl.org.pk/dictionary/65-sentences/7055-i-need-to-apply-for-leave.
#   ⬇️ Downloading: i_need_to_apply_for_leave.mp4
#   ✅ Saved: i_need_to_apply_for_leave.mp4
#
# [134/221] Processing: https://psl.org.pk/dictionary/65-sentences/7056-i-will-be-late
#   ⬇️ Downloading: i_will_be_late.mp4
#   ✅ Saved: i_will_be_late.mp4
#
# [135/221] Processing: https://psl.org.pk/dictionary/65-sentences/7083-after-3-months-visit-again
#   ⬇️ Downloading: after_3_months_visit_again.mp4
#   ✅ Saved: after_3_months_visit_again.mp4
#
# [136/221] Processing: https://psl.org.pk/dictionary/65-sentences/7084-anesthesia-of-eye-numbness-of-eye
#   ⬇️ Downloading: anesthesia_of_eye_numbness_of_eye.mp4
#   ✅ Saved: anesthesia_of_eye_numbness_of_eye.mp4
#
# [137/221] Processing: https://psl.org.pk/dictionary/65-sentences/7085-are-you-muslim-or-non-muslim
#   ⬇️ Downloading: are_you_muslim_or_non_muslim.mp4
#   ✅ Saved: are_you_muslim_or_non_muslim.mp4
#
# [138/221] Processing: https://psl.org.pk/dictionary/65-sentences/7088-are-you-receiving-treatment-from-any-other-doctor-or-hospital
#   ⬇️ Downloading: are_you_receiving_treatment_from_any_other_doctor_or_hospital.mp4
#   ✅ Saved: are_you_receiving_treatment_from_any_other_doctor_or_hospital.mp4
#
# [139/221] Processing: https://psl.org.pk/dictionary/65-sentences/7097-are-you-renting-or-do-you-own-your-house
#   ⬇️ Downloading: are_you_renting_or_do_you_own_your_house.mp4
#   ✅ Saved: are_you_renting_or_do_you_own_your_house.mp4
#
# [140/221] Processing: https://psl.org.pk/dictionary/65-sentences/7098-are-you-taking-consultation-from-another-doctor
#   ⬇️ Downloading: are_you_taking_consultation_from_another_doctor.mp4
#   ✅ Saved: are_you_taking_consultation_from_another_doctor.mp4
#
#   ⬇️ Downloading: how_many_kids_do_you_have.mp4
#   ✅ Saved: how_many_kids_do_you_have.mp4
#
# [170/221] Processing: https://psl.org.pk/dictionary/65-sentences/7128-how-many-times-do-you-pass-urine-at-night
#   ⬇️ Downloading: how_many_times_do_you_pass_urine_at_night.mp4
#   ✅ Saved: how_many_times_do_you_pass_urine_at_night.mp4
#
# [171/221] Processing: https://psl.org.pk/dictionary/65-sentences/7129-i-forgot-to-bring-my-registration-card.
#   ⬇️ Downloading: i_forgot_to_bring_my_registration_card.mp4
#   ✅ Saved: i_forgot_to_bring_my_registration_card.mp4
#
# [172/221] Processing: https://psl.org.pk/dictionary/65-sentences/7130-is-blood-pressure-high-or-low
#   ⬇️ Downloading: is_blood_pressure_high_or_low.mp4
#   ✅ Saved: is_blood_pressure_high_or_low.mp4
#
# [173/221] Processing: https://psl.org.pk/dictionary/65-sentences/7131-is-he-eligible-for-zakat-or-donation-support
#   ⬇️ Downloading: is_he_eligible_for_zakat_or_donation_support.mp4
#   ✅ Saved: is_he_eligible_for_zakat_or_donation_support.mp4
#
# [174/221] Processing: https://psl.org.pk/dictionary/65-sentences/7132-is-the-line-straight-or-crooked
#   ⬇️ Downloading: is_the_line_straight_or_crooked.mp4
#   ✅ Saved: is_the_line_straight_or_crooked.mp4
#
# [175/221] Processing: https://psl.org.pk/dictionary/65-sentences/7133-is-this-your-first-visit
#   ⬇️ Downloading: is_this_your_first_visit.mp4
#   ✅ Saved: is_this_your_first_visit.mp4
#
# [176/221] Processing: https://psl.org.pk/dictionary/65-sentences/7134-is-this-your-follow-up-visit
#   ⬇️ Downloading: is_this_your_follow_up_visit.mp4
#   ✅ Saved: is_this_your_follow_up_visit.mp4
#
# [177/221] Processing: https://psl.org.pk/dictionary/65-sentences/7137-is-your-vision-clear
#   ⬇️ Downloading: is_your_vision_clear.mp4
#   ✅ Saved: is_your_vision_clear.mp4
#
# [178/221] Processing: https://psl.org.pk/dictionary/65-sentences/7138-keep-your-feet-moisturized
#   ⬇️ Downloading: keep_your_feet_moisturized.mp4
#   ✅ Saved: keep_your_feet_moisturized.mp4
#
# [179/221] Processing: https://psl.org.pk/dictionary/65-sentences/7139-need-cash-payment
#   ⬇️ Downloading: need_cash_payment.mp4
#   ✅ Saved: need_cash_payment.mp4
#
# [180/221] Processing: https://psl.org.pk/dictionary/65-sentences/7140-next-time-bring-card-with-you
#   ⬇️ Downloading: next_time_bring_card_with_you.mp4
#   ✅ Saved: next_time_bring_card_with_you.mp4
#
# [181/221] Processing: https://psl.org.pk/dictionary/65-sentences/7141-opd-refraction-department
#   ⬇️ Downloading: opd_refraction_department.mp4
#   ✅ Saved: opd_refraction_department.mp4
#
# [182/221] Processing: https://psl.org.pk/dictionary/65-sentences/7142-operation-in-young-age
#   ⬇️ Downloading: operation_in_young_age.mp4
#   ✅ Saved: operation_in_young_age.mp4
#
# [183/221] Processing: https://psl.org.pk/dictionary/65-sentences/7143-payment-for-blood-test
#   ⬇️ Downloading: payment_for_blood_test.mp4
#   ✅ Saved: payment_for_blood_test.mp4
#
# [184/221] Processing: https://psl.org.pk/dictionary/65-sentences/7144-pediatric-department
#   ⬇️ Downloading: pediatric_department.mp4
#   ✅ Saved: pediatric_department.mp4
#
# [185/221] Processing: https://psl.org.pk/dictionary/65-sentences/7145-registration-room
#   ⬇️ Downloading: registration_room.mp4
#   ✅ Saved: registration_room.mp4
#
# [186/221] Processing: https://psl.org.pk/dictionary/65-sentences/7146-regular-checkup
#   ⬇️ Downloading: regular_checkup.mp4
#   ✅ Saved: regular_checkup.mp4
#
# [187/221] Processing: https://psl.org.pk/dictionary/65-sentences/7147-tests-are-cheap-here
#   ⬇️ Downloading: tests_are_cheap_here.mp4
#   ✅ Saved: tests_are_cheap_here.mp4
#
# [188/221] Processing: https://psl.org.pk/dictionary/65-sentences/7148-tests-are-expensive-in-other-laboratories
#   ⬇️ Downloading: tests_are_expensive_in_other_laboratories.mp4
#   ✅ Saved: tests_are_expensive_in_other_laboratories.mp4
#
# [189/221] Processing: https://psl.org.pk/dictionary/65-sentences/7149-the-eye-s-membrane-needs-to-be-clear
#   ⬇️ Downloading: the_eye_s_membrane_needs_to_be_clear.mp4
#   ✅ Saved: the_eye_s_membrane_needs_to_be_clear.mp4
#
# [190/221] Processing: https://psl.org.pk/dictionary/65-sentences/7150-the-retina-is-weak
#   ⬇️ Downloading: the_retina_is_weak.mp4
#   ✅ Saved: the_retina_is_weak.mp4
#
# [191/221] Processing: https://psl.org.pk/dictionary/65-sentences/7151-use-cotton-socks
#   ⬇️ Downloading: use_cotton_socks.mp4
#   ✅ Saved: use_cotton_socks.mp4
#
# [192/221] Processing: https://psl.org.pk/dictionary/65-sentences/7152-use-cream-before-wearing-socks
#   ⬇️ Downloading: use_cream_before_wearing_socks.mp4
#   ✅ Saved: use_cream_before_wearing_socks.mp4
#
# [193/221] Processing: https://psl.org.pk/dictionary/65-sentences/7153-use-food-chart
#   ⬇️ Downloading: use_food_chart.mp4
#   ✅ Saved: use_food_chart.mp4
#
# [194/221] Processing: https://psl.org.pk/dictionary/65-sentences/7154-use-simple-shoe-with-half-inch-sole
#   ⬇️ Downloading: use_simple_shoe_with_half_inch_sole.mp4
#   ✅ Saved: use_simple_shoe_with_half_inch_sole.mp4
#
# [195/221] Processing: https://psl.org.pk/dictionary/65-sentences/7155-use-smbg-self-management-blood-glucose
#   ⬇️ Downloading: use_smbg_self_management_blood_glucose.mp4
#   ✅ Saved: use_smbg_self_management_blood_glucose.mp4
#
# [196/221] Processing: https://psl.org.pk/dictionary/65-sentences/7158-visit-reference
#   ⬇️ Downloading: visit_reference.mp4
#   ✅ Saved: visit_reference.mp4
#
# [197/221] Processing: https://psl.org.pk/dictionary/65-sentences/7159-we-are-bearing-all-your-expenses
#   ⬇️ Downloading: we_are_bearing_all_your_expenses.mp4
#   ✅ Saved: we_are_bearing_all_your_expenses.mp4
#
# [198/221] Processing: https://psl.org.pk/dictionary/65-sentences/7160-we-are-supporting-you-with-some-amount
#   ⬇️ Downloading: we_are_supporting_you_with_some_amount.mp4
#   ✅ Saved: we_are_supporting_you_with_some_amount.mp4
#
# [199/221] Processing: https://psl.org.pk/dictionary/65-sentences/7161-we-can-t-operate
#   ⬇️ Downloading: we_can_t_operate.mp4
#   ✅ Saved: we_can_t_operate.mp4
#
# [200/221] Processing: https://psl.org.pk/dictionary/65-sentences/7162-welfare-support-amount
#   ⬇️ Downloading: welfare_support_amount.mp4
#   ✅ Saved: welfare_support_amount.mp4
#
# [201/221] Processing: https://psl.org.pk/dictionary/65-sentences/7163-what-are-your-expenses
#   ⬇️ Downloading: what_are_your_expenses.mp4
#   ✅ Saved: what_are_your_expenses.mp4
#
# [202/221] Processing: https://psl.org.pk/dictionary/65-sentences/7164-what-is-the-condition-of-your-current-glasses
#   ⬇️ Downloading: what_is_the_condition_of_your_current_glasses.mp4
#   ✅ Saved: what_is_the_condition_of_your_current_glasses.mp4
#
# [203/221] Processing: https://psl.org.pk/dictionary/65-sentences/7165-what-is-your-father-s-name
#   ⬇️ Downloading: what_is_your_father_s_name.mp4
#   ✅ Saved: what_is_your_father_s_name.mp4
#
# [204/221] Processing: https://psl.org.pk/dictionary/65-sentences/7166-what-is-your-husband-s-name
#   ⬇️ Downloading: what_is_your_husband_s_name.mp4
#   ✅ Saved: what_is_your_husband_s_name.mp4
#
# [205/221] Processing: https://psl.org.pk/dictionary/65-sentences/7167-what-is-your-job
#   ⬇️ Downloading: what_is_your_job.mp4
#   ✅ Saved: what_is_your_job.mp4
#
# [206/221] Processing: https://psl.org.pk/dictionary/65-sentences/7168-what-is-your-monthly-earning
#   ⬇️ Downloading: what_is_your_monthly_earning.mp4
#   ✅ Saved: what_is_your_monthly_earning.mp4
#
# [207/221] Processing: https://psl.org.pk/dictionary/65-sentences/7169-what-is-your-monthly-salary
#   ⬇️ Downloading: what_is_your_monthly_salary.mp4
#   ✅ Saved: what_is_your_monthly_salary.mp4
#
# [208/221] Processing: https://psl.org.pk/dictionary/65-sentences/7170-when-did-you-have-surgery
#   ⬇️ Downloading: when_did_you_have_surgery.mp4
#   ✅ Saved: when_did_you_have_surgery.mp4
#
# [209/221] Processing: https://psl.org.pk/dictionary/65-sentences/7171-when-do-you-need-this-report
#   ⬇️ Downloading: when_do_you_need_this_report.mp4
#   ✅ Saved: when_do_you_need_this_report.mp4
#
# [210/221] Processing: https://psl.org.pk/dictionary/65-sentences/7172-which-medicine-are-you-using
#   ⬇️ Downloading: which_medicine_are_you_using.mp4
#   ✅ Saved: which_medicine_are_you_using.mp4
#
# [211/221] Processing: https://psl.org.pk/dictionary/65-sentences/7173-you-have-cataract-disease
#   ⬇️ Downloading: you_have_cataract_disease.mp4
#   ✅ Saved: you_have_cataract_disease.mp4
#
# [212/221] Processing: https://psl.org.pk/dictionary/65-sentences/7174-your-eye-is-larger-than-normal-size
#   ⬇️ Downloading: your_eye_is_larger_than_normal_size.mp4
#   ✅ Saved: your_eye_is_larger_than_normal_size.mp4
#
# [213/221] Processing: https://psl.org.pk/dictionary/65-sentences/7175-your-eye-is-smaller-than-normal-size
#   ⬇️ Downloading: your_eye_is_smaller_than_normal_size.mp4
#   ✅ Saved: your_eye_is_smaller_than_normal_size.mp4
#
# [214/221] Processing: https://psl.org.pk/dictionary/65-sentences/7176-dry-your-feet-properly-after-taking-a-bath
#   ⬇️ Downloading: dry_your_feet_properly_after_taking_a_bath.mp4
#   ✅ Saved: dry_your_feet_properly_after_taking_a_bath.mp4
#
# [215/221] Processing: https://psl.org.pk/dictionary/65-sentences/7377-eid
#   ⬇️ Downloading: eid.mp4
#   ✅ Saved: eid.mp4
#
# [216/221] Processing: https://psl.org.pk/dictionary/65-sentences/7493-how
#   ⬇️ Downloading: how.mp4
#   ✅ Saved: how.mp4
#
# [217/221] Processing: https://psl.org.pk/dictionary/65-sentences/7514-it-is-fine.
#   ⬇️ Downloading: it_is_fine.mp4
#   ✅ Saved: it_is_fine.mp4
#
# [218/221] Processing: https://psl.org.pk/dictionary/65-sentences/7515-it-s-up-to-you
#   ⬇️ Downloading: it_s_up_to_you.mp4
#   ✅ Saved: it_s_up_to_you.mp4
#
# [219/221] Processing: https://psl.org.pk/dictionary/65-sentences/7743-stay-here-today
#   ⬇️ Downloading: stay_here_today.mp4
#   ✅ Saved: stay_here_today.mp4
#
# [220/221] Processing: https://psl.org.pk/dictionary/65-sentences/7798-what-is-your-e-mail-address
#   ⬇️ Downloading: what_is_your_e_mail_address.mp4
#   ✅ Saved: what_is_your_e_mail_address.mp4
#
# [221/221] Processing: https://psl.org.pk/dictionary/65-sentences/7816-your-language
#   ⬇️ Downloading: your_language.mp4
#   ✅ Saved: your_language.mp4
#
# 🎉 ALL VIDEOS DOWNLOADED SUCCESSFULLY

# %% [markdown]
# ---
# EMBEDDINGS

# %%
import os
import shutil

SOURCE_DIR = "/content/drive/MyDrive/PSL_VIDEOS"
TARGET_DIR = "/content/drive/MyDrive/FRAMES_UPDATED"

os.makedirs(TARGET_DIR, exist_ok=True)

for file in os.listdir(SOURCE_DIR):
    if file.endswith(".mp4"):
        sign_name = os.path.splitext(file)[0].upper()  # hello.mp4 → HELLO

        sign_folder = os.path.join(TARGET_DIR, sign_name)
        os.makedirs(sign_folder, exist_ok=True)

        shutil.move(
            os.path.join(SOURCE_DIR, file),
            os.path.join(sign_folder, file)
        )

print("✅ Videos organized into sign folders")
# Out:
# ✅ Videos organized into sign folders

# %%
# %%bash

# CLIPS_DIR="/content/drive/MyDrive/PSL_VIDEOS"
# FRAMES_DIR="/content/drive/MyDrive/FRAMES_FROM_START"

# mkdir -p "$FRAMES_DIR"

# for class_dir in "$CLIPS_DIR"/*; do
#   [ -d "$class_dir" ] || continue

#   class_name=$(basename "$class_dir")
#   echo "📁 Processing class: $class_name"

#   mkdir -p "$FRAMES_DIR/$class_name"

#   for video in "$class_dir"/*.mp4; do
#     video_name=$(basename "$video" .mp4)
#     echo "  🎬 Extracting from start: $video_name.mp4"

#     ffmpeg -y -loglevel error -i "$video" \
#       "$FRAMES_DIR/$class_name/${video_name}_%05d.jpg"
#   done
# done

# echo "✅ Frame extraction from start complete"

# %%
import os
import cv2
import numpy as np
import tensorflow as tf

# %%
DATASET_DIR = "/content/drive/MyDrive/FRAMES_UPDATED"
EMBEDDINGS_DIR = "/content/drive/MyDrive/EMBEDDINGS_2.0"

IMAGE_HEIGHT = 128
IMAGE_WIDTH = 128
SEQUENCE_LENGTH = 20

os.makedirs(EMBEDDINGS_DIR, exist_ok=True)

# %%
def extract_frames(video_path):
    frames = []
    cap = cv2.VideoCapture(video_path)

    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    skip = max(total_frames // SEQUENCE_LENGTH, 1)

    for i in range(SEQUENCE_LENGTH):
        cap.set(cv2.CAP_PROP_POS_FRAMES, i * skip)
        ret, frame = cap.read()
        if not ret:
            break

        frame = cv2.resize(frame, (IMAGE_WIDTH, IMAGE_HEIGHT))
        frame = frame / 255.0
        frames.append(frame)

    cap.release()
    return np.array(frames)

# %%
base_model = tf.keras.applications.MobileNetV2(
    include_top=False,
    weights="imagenet",
    input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3),
    pooling="avg"
)

base_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
def video_to_embedding(video_path):
    frames = extract_frames(video_path)

    if frames.shape[0] == 0:
        raise ValueError("No frames extracted")

    # Pad if video is too short
    while frames.shape[0] < SEQUENCE_LENGTH:
        frames = np.vstack([frames, frames[-1][None, ...]])

    # Extract features per frame
    frame_embeddings = base_model.predict(frames, verbose=0)

    # Average over time → single embedding
    video_embedding = np.mean(frame_embeddings, axis=0)

    return video_embedding

# %%
for sign_name in os.listdir(DATASET_DIR):
    sign_path = os.path.join(DATASET_DIR, sign_name)

    if not os.path.isdir(sign_path):
        continue

    print(f"🔹 Processing sign: {sign_name}")

    videos = [
        f for f in os.listdir(sign_path)
        if f.lower().endswith(".mp4")
    ]

    if not videos:
        print(f"⚠️ No video found for {sign_name}")
        continue

    video_path = os.path.join(sign_path, videos[0])

    try:
        embedding = video_to_embedding(video_path)

        np.save(
            os.path.join(EMBEDDINGS_DIR, f"{sign_name}.npy"),
            embedding
        )

        print(f"✅ Saved embedding for {sign_name} | shape: {embedding.shape}")

    except Exception as e:
        print(f"❌ Failed for {sign_name}: {e}")
# Out:
# 🔹 Processing sign: PSL_DICTIONARY
# ✅ Saved embedding for PSL_DICTIONARY | shape: (1280,)
# 🔹 Processing sign: ARE_YOU_DEAF
# ✅ Saved embedding for ARE_YOU_DEAF | shape: (1280,)
# 🔹 Processing sign: ARE_YOU_HUNGRY
# ✅ Saved embedding for ARE_YOU_HUNGRY | shape: (1280,)
# 🔹 Processing sign: ARE_YOU_READY
# ✅ Saved embedding for ARE_YOU_READY | shape: (1280,)
# 🔹 Processing sign: ASSALAM_O_ALAIKUM
# ✅ Saved embedding for ASSALAM_O_ALAIKUM | shape: (1280,)
# 🔹 Processing sign: BEWARE
# ✅ Saved embedding for BEWARE | shape: (1280,)
# 🔹 Processing sign: CALL_THE_AMBULANCE
# ✅ Saved embedding for CALL_THE_AMBULANCE | shape: (1280,)
# 🔹 Processing sign: CAN_I_HELP_YOU
# ✅ Saved embedding for CAN_I_HELP_YOU | shape: (1280,)
# 🔹 Processing sign: CAN_I_TAKE_YOUR_ORDER
# ✅ Saved embedding for CAN_I_TAKE_YOUR_ORDER | shape: (1280,)
# 🔹 Processing sign: CAN_I_USE_THE_TOILET
# ✅ Saved embedding for CAN_I_USE_THE_TOILET | shape: (1280,)
# 🔹 Processing sign: CLOSE_THE_DOOR
# ✅ Saved embedding for CLOSE_THE_DOOR | shape: (1280,)
# 🔹 Processing sign: CLOSE_THE_WINDOW
# ✅ Saved embedding for CLOSE_THE_WINDOW | shape: (1280,)
# 🔹 Processing sign: COME_HERE
# ✅ Saved embedding for COME_HERE | shape: (1280,)
# 🔹 Processing sign: COME_VISIT_ME_SOMETIME
# ✅ Saved embedding for COME_VISIT_ME_SOMETIME | shape: (1280,)
# 🔹 Processing sign: CONGRATULATIONS
# ✅ Saved embedding for CONGRATULATIONS | shape: (1280,)
# 🔹 Processing sign: DID_YOU_ASK_HIM
# ✅ Saved embedding for DID_YOU_ASK_HIM | shape: (1280,)
# 🔹 Processing sign: DID_YOU_EAT
# ✅ Saved embedding for DID_YOU_EAT | shape: (1280,)
# 🔹 Processing sign: DID_YOU_PASS_OR_FAIL
# ✅ Saved embedding for DID_YOU_PASS_OR_FAIL | shape: (1280,)
# 🔹 Processing sign: DID_YOU_UNDERSTAND
# ✅ Saved embedding for DID_YOU_UNDERSTAND | shape: (1280,)
# 🔹 Processing sign: DO_YOU_ALLOW_ANIMALS
# ✅ Saved embedding for DO_YOU_ALLOW_ANIMALS | shape: (1280,)
# 🔹 Processing sign: DO_YOU_FEEL_ALL_RIGHT
# ✅ Saved embedding for DO_YOU_FEEL_ALL_RIGHT | shape: (1280,)
# 🔹 Processing sign: DO_YOU_GO_TO_SCHOOL
# ✅ Saved embedding for DO_YOU_GO_TO_SCHOOL | shape: (1280,)
# 🔹 Processing sign: DO_YOU_HAVE_A_PET
# ✅ Saved embedding for DO_YOU_HAVE_A_PET | shape: (1280,)
# 🔹 Processing sign: DO_YOU_HAVE_ANY_ASPIRIN
# ✅ Saved embedding for DO_YOU_HAVE_ANY_ASPIRIN | shape: (1280,)
# 🔹 Processing sign: DO_YOU_HAVE_MORE_OF_THIS
# ✅ Saved embedding for DO_YOU_HAVE_MORE_OF_THIS | shape: (1280,)
# 🔹 Processing sign: DO_YOU_KNOW_WHERE_I_CAN_FIND_A_ROOM_HERE
# ✅ Saved embedding for DO_YOU_KNOW_WHERE_I_CAN_FIND_A_ROOM_HERE | shape: (1280,)
# 🔹 Processing sign: DO_YOU_LIKE_TO_WATCH_TV
# ✅ Saved embedding for DO_YOU_LIKE_TO_WATCH_TV | shape: (1280,)
# 🔹 Processing sign: DO_YOU_SPEAK_ENGLISH
# ✅ Saved embedding for DO_YOU_SPEAK_ENGLISH | shape: (1280,)
# 🔹 Processing sign: DO_YOU_USE_A_HEARING_AID
# ✅ Saved embedding for DO_YOU_USE_A_HEARING_AID | shape: (1280,)
# 🔹 Processing sign: DO_YOU_WANT_A_SOFT_DRINK
# ✅ Saved embedding for DO_YOU_WANT_A_SOFT_DRINK | shape: (1280,)
# 🔹 Processing sign: DO_YOU_WANT_MILK_AND_SUGAR
# ✅ Saved embedding for DO_YOU_WANT_MILK_AND_SUGAR | shape: (1280,)
# 🔹 Processing sign: DO_YOU_WANT_TO_GO_TO_THE_MOVIES
# ✅ Saved embedding for DO_YOU_WANT_TO_GO_TO_THE_MOVIES | shape: (1280,)
# 🔹 Processing sign: DOESN_T_MATTER
# ✅ Saved embedding for DOESN_T_MATTER | shape: (1280,)
# 🔹 Processing sign: DON_T_TOUCH
# ✅ Saved embedding for DON_T_TOUCH | shape: (1280,)
# 🔹 Processing sign: EID_MUBARAK
# ✅ Saved embedding for EID_MUBARAK | shape: (1280,)
# 🔹 Processing sign: EXCUSE_ME
# ✅ Saved embedding for EXCUSE_ME | shape: (1280,)
# 🔹 Processing sign: GO_AWAY
# ✅ Saved embedding for GO_AWAY | shape: (1280,)
# 🔹 Processing sign: GOOD_AFTERNOON
# ✅ Saved embedding for GOOD_AFTERNOON | shape: (1280,)
# 🔹 Processing sign: GOOD_EVENING
# ✅ Saved embedding for GOOD_EVENING | shape: (1280,)
# 🔹 Processing sign: GOOD_MORNING
# ✅ Saved embedding for GOOD_MORNING | shape: (1280,)
# 🔹 Processing sign: GOOD_NIGHT
# ✅ Saved embedding for GOOD_NIGHT | shape: (1280,)
# 🔹 Processing sign: GOODBYE
# ✅ Saved embedding for GOODBYE | shape: (1280,)
# 🔹 Processing sign: HAPPY_NEW_YEAR
# ✅ Saved embedding for HAPPY_NEW_YEAR | shape: (1280,)
# 🔹 Processing sign: HAVE_A_NICE_DAY
# ✅ Saved embedding for HAVE_A_NICE_DAY | shape: (1280,)
# 🔹 Processing sign: HAVE_YOU_EATEN
# ✅ Saved embedding for HAVE_YOU_EATEN | shape: (1280,)
# 🔹 Processing sign: HELLO
# ✅ Saved embedding for HELLO | shape: (1280,)
# 🔹 Processing sign: HOW_ARE_YOU
# ✅ Saved embedding for HOW_ARE_YOU | shape: (1280,)
# 🔹 Processing sign: HOW_CAN_I_HELP_YOU
# ✅ Saved embedding for HOW_CAN_I_HELP_YOU | shape: (1280,)
# 🔹 Processing sign: HOW_DO_I_GET_THERE
# ✅ Saved embedding for HOW_DO_I_GET_THERE | shape: (1280,)
# 🔹 Processing sign: HOW_DO_YOU_FEEL
# ✅ Saved embedding for HOW_DO_YOU_FEEL | shape: (1280,)
# 🔹 Processing sign: HOW_FAR_IS_IT
# ✅ Saved embedding for HOW_FAR_IS_IT | shape: (1280,)
# 🔹 Processing sign: HOW_FAR
# ✅ Saved embedding for HOW_FAR | shape: (1280,)
# 🔹 Processing sign: HOW_LONG_ARE_YOU_STAYING
# ✅ Saved embedding for HOW_LONG_ARE_YOU_STAYING | shape: (1280,)
# 🔹 Processing sign: HOW_LONG
# ✅ Saved embedding for HOW_LONG | shape: (1280,)
# 🔹 Processing sign: HOW_MANY_CHILDREN_DO_YOU_HAVE
# ✅ Saved embedding for HOW_MANY_CHILDREN_DO_YOU_HAVE | shape: (1280,)
# 🔹 Processing sign: HOW_MANY
# ✅ Saved embedding for HOW_MANY | shape: (1280,)
# 🔹 Processing sign: HOW_MUCH_DOES_IT_COST
# ✅ Saved embedding for HOW_MUCH_DOES_IT_COST | shape: (1280,)
# 🔹 Processing sign: HOW_MUCH
# ✅ Saved embedding for HOW_MUCH | shape: (1280,)
# 🔹 Processing sign: HOW_OFTEN
# ✅ Saved embedding for HOW_OFTEN | shape: (1280,)
# 🔹 Processing sign: HOW_OLD_ARE_YOU
# ✅ Saved embedding for HOW_OLD_ARE_YOU | shape: (1280,)
# 🔹 Processing sign: HOW_QUESTION
# ✅ Saved embedding for HOW_QUESTION | shape: (1280,)
# 🔹 Processing sign: I_AM_A_STUDENT
# ✅ Saved embedding for I_AM_A_STUDENT | shape: (1280,)
# 🔹 Processing sign: I_AM_LEARNING_SIGN_LANGUAGE
# ✅ Saved embedding for I_AM_LEARNING_SIGN_LANGUAGE | shape: (1280,)
# 🔹 Processing sign: I_AM_STUDYING_TO_BE_AN_INTERPRETER
# ✅ Saved embedding for I_AM_STUDYING_TO_BE_AN_INTERPRETER | shape: (1280,)
# 🔹 Processing sign: I_DO_NOT_BELIEVE_YOU
# ✅ Saved embedding for I_DO_NOT_BELIEVE_YOU | shape: (1280,)
# 🔹 Processing sign: I_DO_NOT_LIKE_THIS
# ✅ Saved embedding for I_DO_NOT_LIKE_THIS | shape: (1280,)
# 🔹 Processing sign: I_DO_NOT_UNDERSTAND
# ✅ Saved embedding for I_DO_NOT_UNDERSTAND | shape: (1280,)
# 🔹 Processing sign: I_HAVE_A_QUESTION
# ✅ Saved embedding for I_HAVE_A_QUESTION | shape: (1280,)
# 🔹 Processing sign: I_HAVE_TO_BUY_SOME_MEDICINE
# ✅ Saved embedding for I_HAVE_TO_BUY_SOME_MEDICINE | shape: (1280,)
# 🔹 Processing sign: I_HAVE_TO_GO_SHOPPING
# ✅ Saved embedding for I_HAVE_TO_GO_SHOPPING | shape: (1280,)
# 🔹 Processing sign: I_LIKE_TO_COMPLETE_MY_WORK_EARLY
# ✅ Saved embedding for I_LIKE_TO_COMPLETE_MY_WORK_EARLY | shape: (1280,)
# 🔹 Processing sign: I_NEED_TO_GO_TO_THE_BANK
# ✅ Saved embedding for I_NEED_TO_GO_TO_THE_BANK | shape: (1280,)
# 🔹 Processing sign: I_NEED_TO_WASH_MY_SHIRT
# ✅ Saved embedding for I_NEED_TO_WASH_MY_SHIRT | shape: (1280,)
# 🔹 Processing sign: I_SPEAK_A_LITTLE_BIT
# ✅ Saved embedding for I_SPEAK_A_LITTLE_BIT | shape: (1280,)
# 🔹 Processing sign: I_STARTED_A_COMPUTER_CLASS_TODAY
# ✅ Saved embedding for I_STARTED_A_COMPUTER_CLASS_TODAY | shape: (1280,)
# 🔹 Processing sign: I_STUDIED_ALL_NIGHT
# ✅ Saved embedding for I_STUDIED_ALL_NIGHT | shape: (1280,)
# 🔹 Processing sign: I_WANT_TO_VISIT_THE_DEAF_CLUB
# ✅ Saved embedding for I_WANT_TO_VISIT_THE_DEAF_CLUB | shape: (1280,)
# 🔹 Processing sign: I_WAS_BORN_DEAF
# ✅ Saved embedding for I_WAS_BORN_DEAF | shape: (1280,)
# 🔹 Processing sign: I_WENT_TO_A_SCHOOL_FOR_HEARING_CHILDREN
# ✅ Saved embedding for I_WENT_TO_A_SCHOOL_FOR_HEARING_CHILDREN | shape: (1280,)
# 🔹 Processing sign: I_WILL_BE_BACK_SOON
# ✅ Saved embedding for I_WILL_BE_BACK_SOON | shape: (1280,)
# 🔹 Processing sign: I_WOULD_LIKE_TO_INTERVIEW_FOR_THIS_JOB
# ✅ Saved embedding for I_WOULD_LIKE_TO_INTERVIEW_FOR_THIS_JOB | shape: (1280,)
# 🔹 Processing sign: I_LL_SEE_YOU_LATER
# ✅ Saved embedding for I_LL_SEE_YOU_LATER | shape: (1280,)
# 🔹 Processing sign: IS_IT_BROKEN
# ✅ Saved embedding for IS_IT_BROKEN | shape: (1280,)
# 🔹 Processing sign: IS_IT_FAR_FROM_HERE
# ✅ Saved embedding for IS_IT_FAR_FROM_HERE | shape: (1280,)
# 🔹 Processing sign: IS_IT_TRUE
# ✅ Saved embedding for IS_IT_TRUE | shape: (1280,)
# 🔹 Processing sign: IS_SOMEBODY_MEETING_YOU
# ✅ Saved embedding for IS_SOMEBODY_MEETING_YOU | shape: (1280,)
# 🔹 Processing sign: IS_THAT_ENOUGH_FOR_YOU
# ✅ Saved embedding for IS_THAT_ENOUGH_FOR_YOU | shape: (1280,)
# 🔹 Processing sign: IT_WAS_COLD_THIS_MORNING
# ✅ Saved embedding for IT_WAS_COLD_THIS_MORNING | shape: (1280,)
# 🔹 Processing sign: LET_S_GO_TO_A_RESTAURANT
# ✅ Saved embedding for LET_S_GO_TO_A_RESTAURANT | shape: (1280,)
# 🔹 Processing sign: MATH_IS_A_DIFFICULT_SUBJECT_FOR_ME
# ✅ Saved embedding for MATH_IS_A_DIFFICULT_SUBJECT_FOR_ME | shape: (1280,)
# 🔹 Processing sign: MAY_I_HAVE_YOUR_BUSINESS_CARD
# ✅ Saved embedding for MAY_I_HAVE_YOUR_BUSINESS_CARD | shape: (1280,)
# 🔹 Processing sign: MAYBE
# ✅ Saved embedding for MAYBE | shape: (1280,)
# 🔹 Processing sign: MAYBE_IT_WILL_RAIN_TOMORROW
# ✅ Saved embedding for MAYBE_IT_WILL_RAIN_TOMORROW | shape: (1280,)
# 🔹 Processing sign: MY_BROTHER_IS_YOUNGER_THAN_ME
# ✅ Saved embedding for MY_BROTHER_IS_YOUNGER_THAN_ME | shape: (1280,)
# 🔹 Processing sign: MY_INTERNET_CONNECTION_IS_SLOW
# ✅ Saved embedding for MY_INTERNET_CONNECTION_IS_SLOW | shape: (1280,)
# 🔹 Processing sign: MY_NAME_IS
# ✅ Saved embedding for MY_NAME_IS | shape: (1280,)
# 🔹 Processing sign: MY_SIGN_LANGUAGE_HAS_ALREADY_IMPROVED
# ✅ Saved embedding for MY_SIGN_LANGUAGE_HAS_ALREADY_IMPROVED | shape: (1280,)
# 🔹 Processing sign: NICE_TO_MEET_YOU
# ✅ Saved embedding for NICE_TO_MEET_YOU | shape: (1280,)
# 🔹 Processing sign: NO_TALKING_DURING_THE_TEST
# ✅ Saved embedding for NO_TALKING_DURING_THE_TEST | shape: (1280,)
# 🔹 Processing sign: PLEASE
# ✅ Saved embedding for PLEASE | shape: (1280,)
# 🔹 Processing sign: SEE_YOU_LATER
# ✅ Saved embedding for SEE_YOU_LATER | shape: (1280,)
# 🔹 Processing sign: SIGN_SLOWLY_PLEASE
# ✅ Saved embedding for SIGN_SLOWLY_PLEASE | shape: (1280,)
# 🔹 Processing sign: SIXTY_THOUSAND_PEOPLE_LIVE_IN_MY_CITY
# ✅ Saved embedding for SIXTY_THOUSAND_PEOPLE_LIVE_IN_MY_CITY | shape: (1280,)
# 🔹 Processing sign: SMOKING_IS_NOT_ALLOWED
# ✅ Saved embedding for SMOKING_IS_NOT_ALLOWED | shape: (1280,)
# 🔹 Processing sign: THANK_YOU
# ✅ Saved embedding for THANK_YOU | shape: (1280,)
# 🔹 Processing sign: THANK_YOU_FOR_DINING_WITH_US
# ✅ Saved embedding for THANK_YOU_FOR_DINING_WITH_US | shape: (1280,)
# 🔹 Processing sign: THE_CAKE_IS_IN_THE_OVEN
# ✅ Saved embedding for THE_CAKE_IS_IN_THE_OVEN | shape: (1280,)
# 🔹 Processing sign: THE_FLIGHT_HAS_BEEN_DELAYED_AN_HOUR
# ✅ Saved embedding for THE_FLIGHT_HAS_BEEN_DELAYED_AN_HOUR | shape: (1280,)
# 🔹 Processing sign: THE_GARBAGE_TRUCK_COMES_ONCE_A_WEEK
# ✅ Saved embedding for THE_GARBAGE_TRUCK_COMES_ONCE_A_WEEK | shape: (1280,)
# 🔹 Processing sign: THE_POLICE_STATION_IS_TWO_BLOCKS_AWAY
# ✅ Saved embedding for THE_POLICE_STATION_IS_TWO_BLOCKS_AWAY | shape: (1280,)
# 🔹 Processing sign: THE_TEACHER_ASKED_ME_A_LOT_OF_QUESTIONS
# ✅ Saved embedding for THE_TEACHER_ASKED_ME_A_LOT_OF_QUESTIONS | shape: (1280,)
# 🔹 Processing sign: THERE_HAS_BEEN_AN_ACCIDENT
# ✅ Saved embedding for THERE_HAS_BEEN_AN_ACCIDENT | shape: (1280,)
# 🔹 Processing sign: THERE_IS_NO_SIGN_FOR_THAT_YOU_HAVE_TO_FINGERSPELL_IT
# ✅ Saved embedding for THERE_IS_NO_SIGN_FOR_THAT_YOU_HAVE_TO_FINGERSPELL_IT | shape: (1280,)
# 🔹 Processing sign: THIS_IS_VERY_IMPORTANT
# ✅ Saved embedding for THIS_IS_VERY_IMPORTANT | shape: (1280,)
# 🔹 Processing sign: WALAIKUM_AS_SALAAM
# ✅ Saved embedding for WALAIKUM_AS_SALAAM | shape: (1280,)
# 🔹 Processing sign: WELCOME
# ✅ Saved embedding for WELCOME | shape: (1280,)
# 🔹 Processing sign: WELL_DONE
# ✅ Saved embedding for WELL_DONE | shape: (1280,)
# 🔹 Processing sign: WHAT_FOR
# ✅ Saved embedding for WHAT_FOR | shape: (1280,)
# 🔹 Processing sign: WHAT_IS_YOUR_EMAIL_ADDRESS
# ✅ Saved embedding for WHAT_IS_YOUR_EMAIL_ADDRESS | shape: (1280,)
# 🔹 Processing sign: WHAT_IS_YOUR_NAME
# ✅ Saved embedding for WHAT_IS_YOUR_NAME | shape: (1280,)
# 🔹 Processing sign: WHAT_IS_YOUR_TELEPHONE_NUMBER
# ✅ Saved embedding for WHAT_IS_YOUR_TELEPHONE_NUMBER | shape: (1280,)
# 🔹 Processing sign: WHAT
# ✅ Saved embedding for WHAT | shape: (1280,)
# 🔹 Processing sign: WHEN
# ✅ Saved embedding for WHEN | shape: (1280,)
# 🔹 Processing sign: WHERE_DO_YOU_LIVE
# ✅ Saved embedding for WHERE_DO_YOU_LIVE | shape: (1280,)
# 🔹 Processing sign: WHERE
# ✅ Saved embedding for WHERE | shape: (1280,)
# 🔹 Processing sign: WHICH
# ✅ Saved embedding for WHICH | shape: (1280,)
# 🔹 Processing sign: WHO
# ✅ Saved embedding for WHO | shape: (1280,)
# 🔹 Processing sign: WHOSE
# ✅ Saved embedding for WHOSE | shape: (1280,)
# 🔹 Processing sign: WHY
# ✅ Saved embedding for WHY | shape: (1280,)
# 🔹 Processing sign: WITH_WHOM
# ✅ Saved embedding for WITH_WHOM | shape: (1280,)
# 🔹 Processing sign: WOW_EXCITEMENT
# ✅ Saved embedding for WOW_EXCITEMENT | shape: (1280,)
# 🔹 Processing sign: YES
# ❌ Failed for YES: No frames extracted
# 🔹 Processing sign: I_AM_SICK
# ✅ Saved embedding for I_AM_SICK | shape: (1280,)
# 🔹 Processing sign: I_NEED_TO_APPLY_FOR_LEAVE
# ✅ Saved embedding for I_NEED_TO_APPLY_FOR_LEAVE | shape: (1280,)
# 🔹 Processing sign: I_WILL_BE_LATE
# ✅ Saved embedding for I_WILL_BE_LATE | shape: (1280,)
# 🔹 Processing sign: AFTER_3_MONTHS_VISIT_AGAIN
# ✅ Saved embedding for AFTER_3_MONTHS_VISIT_AGAIN | shape: (1280,)
# 🔹 Processing sign: ANESTHESIA_OF_EYE_NUMBNESS_OF_EYE
# ✅ Saved embedding for ANESTHESIA_OF_EYE_NUMBNESS_OF_EYE | shape: (1280,)
# 🔹 Processing sign: ARE_YOU_MUSLIM_OR_NON_MUSLIM
# ✅ Saved embedding for ARE_YOU_MUSLIM_OR_NON_MUSLIM | shape: (1280,)
# 🔹 Processing sign: ARE_YOU_RECEIVING_TREATMENT_FROM_ANY_OTHER_DOCTOR_OR_HOSPITAL
# ✅ Saved embedding for ARE_YOU_RECEIVING_TREATMENT_FROM_ANY_OTHER_DOCTOR_OR_HOSPITAL | shape: (1280,)
# 🔹 Processing sign: ARE_YOU_RENTING_OR_DO_YOU_OWN_YOUR_HOUSE
# ✅ Saved embedding for ARE_YOU_RENTING_OR_DO_YOU_OWN_YOUR_HOUSE | shape: (1280,)
# 🔹 Processing sign: ARE_YOU_TAKING_CONSULTATION_FROM_ANOTHER_DOCTOR
# ✅ Saved embedding for ARE_YOU_TAKING_CONSULTATION_FROM_ANOTHER_DOCTOR | shape: (1280,)
# 🔹 Processing sign: ARE_YOU_WEARING_GLASSES_FOR_THE_FIRST_TIME
# ✅ Saved embedding for ARE_YOU_WEARING_GLASSES_FOR_THE_FIRST_TIME | shape: (1280,)
# 🔹 Processing sign: CHECK_YOUR_FEET_DAILY
# ✅ Saved embedding for CHECK_YOUR_FEET_DAILY | shape: (1280,)
# 🔹 Processing sign: CHECKUP_OF_YOUR_EYE_SIGHT
# ✅ Saved embedding for CHECKUP_OF_YOUR_EYE_SIGHT | shape: (1280,)
# 🔹 Processing sign: CHEMICAL_INJURY_OF_EYES
# ✅ Saved embedding for CHEMICAL_INJURY_OF_EYES | shape: (1280,)
# 🔹 Processing sign: COME_TOMORROW_FOR_SURGERY
# ✅ Saved embedding for COME_TOMORROW_FOR_SURGERY | shape: (1280,)
# 🔹 Processing sign: CUT_YOUR_NAILS_AFTER_BATH_AND_DON_T_CUT_CORNERS
# ✅ Saved embedding for CUT_YOUR_NAILS_AFTER_BATH_AND_DON_T_CUT_CORNERS | shape: (1280,)
# 🔹 Processing sign: DO_YOU_FEEL_DIZZY
# ✅ Saved embedding for DO_YOU_FEEL_DIZZY | shape: (1280,)
# 🔹 Processing sign: DO_YOU_FEEL_ITCHING
# ✅ Saved embedding for DO_YOU_FEEL_ITCHING | shape: (1280,)
# 🔹 Processing sign: DO_YOU_HAVE_ANY_DEBTS
# ✅ Saved embedding for DO_YOU_HAVE_ANY_DEBTS | shape: (1280,)
# 🔹 Processing sign: DO_YOU_HAVE_ANY_ASSETS
# ✅ Saved embedding for DO_YOU_HAVE_ANY_ASSETS | shape: (1280,)
# 🔹 Processing sign: DO_YOU_HAVE_BRUISE_OR_IRRITATION_IN_YOUR_FEET
# ✅ Saved embedding for DO_YOU_HAVE_BRUISE_OR_IRRITATION_IN_YOUR_FEET | shape: (1280,)
# 🔹 Processing sign: DO_YOU_HAVE_DIABETES
# ✅ Saved embedding for DO_YOU_HAVE_DIABETES | shape: (1280,)
# 🔹 Processing sign: DO_YOU_HAVE_GOLD_SILVER
# ✅ Saved embedding for DO_YOU_HAVE_GOLD_SILVER | shape: (1280,)
# 🔹 Processing sign: DO_YOU_HAVE_TRADE_ITEMS
# ✅ Saved embedding for DO_YOU_HAVE_TRADE_ITEMS | shape: (1280,)
# 🔹 Processing sign: DO_YOUR_HANDS_FEET_GET_NUMB
# ✅ Saved embedding for DO_YOUR_HANDS_FEET_GET_NUMB | shape: (1280,)
# 🔹 Processing sign: DOES_ANYONE_IN_YOUR_FAMILY_HAVE_DIABETES
# ✅ Saved embedding for DOES_ANYONE_IN_YOUR_FAMILY_HAVE_DIABETES | shape: (1280,)
# 🔹 Processing sign: DOES_YOUR_EYE_FEEL_ITCHY
# ✅ Saved embedding for DOES_YOUR_EYE_FEEL_ITCHY | shape: (1280,)
# 🔹 Processing sign: DON_T_BE_AFRAID
# ✅ Saved embedding for DON_T_BE_AFRAID | shape: (1280,)
# 🔹 Processing sign: DON_T_PUT_PRESSURE_ON_YOUR_EYE
# ✅ Saved embedding for DON_T_PUT_PRESSURE_ON_YOUR_EYE | shape: (1280,)
# 🔹 Processing sign: DON_T_WALK_WITH_BARE_FEET_ON_GRASS
# ✅ Saved embedding for DON_T_WALK_WITH_BARE_FEET_ON_GRASS | shape: (1280,)
# 🔹 Processing sign: DURING_STUDIES_IS_YOUR_VISION_WEAK
# ✅ Saved embedding for DURING_STUDIES_IS_YOUR_VISION_WEAK | shape: (1280,)
# 🔹 Processing sign: EYE_IS_RED
# ✅ Saved embedding for EYE_IS_RED | shape: (1280,)
# 🔹 Processing sign: FAMILY_MEDICAL_HISTORY
# ✅ Saved embedding for FAMILY_MEDICAL_HISTORY | shape: (1280,)
# 🔹 Processing sign: FEELING_OF_HOTNESS_OR_COLDNESS
# ✅ Saved embedding for FEELING_OF_HOTNESS_OR_COLDNESS | shape: (1280,)
# 🔹 Processing sign: HOW_LONG_HAVE_YOU_BEEN_DIABETIC
# ✅ Saved embedding for HOW_LONG_HAVE_YOU_BEEN_DIABETIC | shape: (1280,)
# 🔹 Processing sign: HOW_LONG_HAVE_YOU_BEEN_FACING_THIS_PROBLEM
# ✅ Saved embedding for HOW_LONG_HAVE_YOU_BEEN_FACING_THIS_PROBLEM | shape: (1280,)
# 🔹 Processing sign: HOW_LONG_HAVE_YOU_BEEN_SUFFERING_WITH_THIS_DISEASE
# ✅ Saved embedding for HOW_LONG_HAVE_YOU_BEEN_SUFFERING_WITH_THIS_DISEASE | shape: (1280,)
# 🔹 Processing sign: HOW_LONG_HAVE_YOU_BEEN_WEARING_GLASSES
# ✅ Saved embedding for HOW_LONG_HAVE_YOU_BEEN_WEARING_GLASSES | shape: (1280,)
# 🔹 Processing sign: HOW_MANY_KIDS_DO_YOU_HAVE
# ✅ Saved embedding for HOW_MANY_KIDS_DO_YOU_HAVE | shape: (1280,)
# 🔹 Processing sign: HOW_MANY_TIMES_DO_YOU_PASS_URINE_AT_NIGHT
# ✅ Saved embedding for HOW_MANY_TIMES_DO_YOU_PASS_URINE_AT_NIGHT | shape: (1280,)
# 🔹 Processing sign: I_FORGOT_TO_BRING_MY_REGISTRATION_CARD
# ✅ Saved embedding for I_FORGOT_TO_BRING_MY_REGISTRATION_CARD | shape: (1280,)
# 🔹 Processing sign: IS_BLOOD_PRESSURE_HIGH_OR_LOW
# ✅ Saved embedding for IS_BLOOD_PRESSURE_HIGH_OR_LOW | shape: (1280,)
# 🔹 Processing sign: IS_HE_ELIGIBLE_FOR_ZAKAT_OR_DONATION_SUPPORT
# ✅ Saved embedding for IS_HE_ELIGIBLE_FOR_ZAKAT_OR_DONATION_SUPPORT | shape: (1280,)
# 🔹 Processing sign: IS_THE_LINE_STRAIGHT_OR_CROOKED
# ✅ Saved embedding for IS_THE_LINE_STRAIGHT_OR_CROOKED | shape: (1280,)
# 🔹 Processing sign: IS_THIS_YOUR_FIRST_VISIT
# ✅ Saved embedding for IS_THIS_YOUR_FIRST_VISIT | shape: (1280,)
# 🔹 Processing sign: IS_THIS_YOUR_FOLLOW_UP_VISIT
# ✅ Saved embedding for IS_THIS_YOUR_FOLLOW_UP_VISIT | shape: (1280,)
# 🔹 Processing sign: IS_YOUR_VISION_CLEAR
# ✅ Saved embedding for IS_YOUR_VISION_CLEAR | shape: (1280,)
# 🔹 Processing sign: KEEP_YOUR_FEET_MOISTURIZED
# ✅ Saved embedding for KEEP_YOUR_FEET_MOISTURIZED | shape: (1280,)
# 🔹 Processing sign: NEED_CASH_PAYMENT
# ✅ Saved embedding for NEED_CASH_PAYMENT | shape: (1280,)
# 🔹 Processing sign: NEXT_TIME_BRING_CARD_WITH_YOU
# ✅ Saved embedding for NEXT_TIME_BRING_CARD_WITH_YOU | shape: (1280,)
# 🔹 Processing sign: OPD_REFRACTION_DEPARTMENT
# ✅ Saved embedding for OPD_REFRACTION_DEPARTMENT | shape: (1280,)
# 🔹 Processing sign: OPERATION_IN_YOUNG_AGE
# ✅ Saved embedding for OPERATION_IN_YOUNG_AGE | shape: (1280,)
# 🔹 Processing sign: PAYMENT_FOR_BLOOD_TEST
# ✅ Saved embedding for PAYMENT_FOR_BLOOD_TEST | shape: (1280,)
# 🔹 Processing sign: PEDIATRIC_DEPARTMENT
# ✅ Saved embedding for PEDIATRIC_DEPARTMENT | shape: (1280,)
# 🔹 Processing sign: REGISTRATION_ROOM
# ✅ Saved embedding for REGISTRATION_ROOM | shape: (1280,)
# 🔹 Processing sign: REGULAR_CHECKUP
# ✅ Saved embedding for REGULAR_CHECKUP | shape: (1280,)
# 🔹 Processing sign: TESTS_ARE_CHEAP_HERE
# ✅ Saved embedding for TESTS_ARE_CHEAP_HERE | shape: (1280,)
# 🔹 Processing sign: TESTS_ARE_EXPENSIVE_IN_OTHER_LABORATORIES
# ✅ Saved embedding for TESTS_ARE_EXPENSIVE_IN_OTHER_LABORATORIES | shape: (1280,)
# 🔹 Processing sign: THE_EYE_S_MEMBRANE_NEEDS_TO_BE_CLEAR
# ✅ Saved embedding for THE_EYE_S_MEMBRANE_NEEDS_TO_BE_CLEAR | shape: (1280,)
# 🔹 Processing sign: THE_RETINA_IS_WEAK
# ✅ Saved embedding for THE_RETINA_IS_WEAK | shape: (1280,)
# 🔹 Processing sign: USE_COTTON_SOCKS
# ✅ Saved embedding for USE_COTTON_SOCKS | shape: (1280,)
# 🔹 Processing sign: USE_CREAM_BEFORE_WEARING_SOCKS
# ✅ Saved embedding for USE_CREAM_BEFORE_WEARING_SOCKS | shape: (1280,)
# 🔹 Processing sign: USE_FOOD_CHART
# ✅ Saved embedding for USE_FOOD_CHART | shape: (1280,)
# 🔹 Processing sign: USE_SIMPLE_SHOE_WITH_HALF_INCH_SOLE
# ✅ Saved embedding for USE_SIMPLE_SHOE_WITH_HALF_INCH_SOLE | shape: (1280,)
# 🔹 Processing sign: USE_SMBG_SELF_MANAGEMENT_BLOOD_GLUCOSE
# ✅ Saved embedding for USE_SMBG_SELF_MANAGEMENT_BLOOD_GLUCOSE | shape: (1280,)
# 🔹 Processing sign: VISIT_REFERENCE
# ✅ Saved embedding for VISIT_REFERENCE | shape: (1280,)
# 🔹 Processing sign: WE_ARE_BEARING_ALL_YOUR_EXPENSES
# ✅ Saved embedding for WE_ARE_BEARING_ALL_YOUR_EXPENSES | shape: (1280,)
# 🔹 Processing sign: WE_ARE_SUPPORTING_YOU_WITH_SOME_AMOUNT
# ✅ Saved embedding for WE_ARE_SUPPORTING_YOU_WITH_SOME_AMOUNT | shape: (1280,)
# 🔹 Processing sign: WE_CAN_T_OPERATE
# ✅ Saved embedding for WE_CAN_T_OPERATE | shape: (1280,)
# 🔹 Processing sign: WELFARE_SUPPORT_AMOUNT
# ✅ Saved embedding for WELFARE_SUPPORT_AMOUNT | shape: (1280,)
# 🔹 Processing sign: WHAT_ARE_YOUR_EXPENSES
# ✅ Saved embedding for WHAT_ARE_YOUR_EXPENSES | shape: (1280,)
# 🔹 Processing sign: WHAT_IS_THE_CONDITION_OF_YOUR_CURRENT_GLASSES
# ✅ Saved embedding for WHAT_IS_THE_CONDITION_OF_YOUR_CURRENT_GLASSES | shape: (1280,)
# 🔹 Processing sign: WHAT_IS_YOUR_FATHER_S_NAME
# ✅ Saved embedding for WHAT_IS_YOUR_FATHER_S_NAME | shape: (1280,)
# 🔹 Processing sign: WHAT_IS_YOUR_HUSBAND_S_NAME
# ✅ Saved embedding for WHAT_IS_YOUR_HUSBAND_S_NAME | shape: (1280,)
# 🔹 Processing sign: WHAT_IS_YOUR_JOB
# ✅ Saved embedding for WHAT_IS_YOUR_JOB | shape: (1280,)
# 🔹 Processing sign: WHAT_IS_YOUR_MONTHLY_EARNING
# ✅ Saved embedding for WHAT_IS_YOUR_MONTHLY_EARNING | shape: (1280,)
# 🔹 Processing sign: WHAT_IS_YOUR_MONTHLY_SALARY
# ✅ Saved embedding for WHAT_IS_YOUR_MONTHLY_SALARY | shape: (1280,)
# 🔹 Processing sign: WHEN_DID_YOU_HAVE_SURGERY
# ✅ Saved embedding for WHEN_DID_YOU_HAVE_SURGERY | shape: (1280,)
# 🔹 Processing sign: WHEN_DO_YOU_NEED_THIS_REPORT
# ✅ Saved embedding for WHEN_DO_YOU_NEED_THIS_REPORT | shape: (1280,)
# 🔹 Processing sign: WHICH_MEDICINE_ARE_YOU_USING
# ✅ Saved embedding for WHICH_MEDICINE_ARE_YOU_USING | shape: (1280,)
# 🔹 Processing sign: YOU_HAVE_CATARACT_DISEASE
# ✅ Saved embedding for YOU_HAVE_CATARACT_DISEASE | shape: (1280,)
# 🔹 Processing sign: YOUR_EYE_IS_LARGER_THAN_NORMAL_SIZE
# ✅ Saved embedding for YOUR_EYE_IS_LARGER_THAN_NORMAL_SIZE | shape: (1280,)
# 🔹 Processing sign: YOUR_EYE_IS_SMALLER_THAN_NORMAL_SIZE
# ✅ Saved embedding for YOUR_EYE_IS_SMALLER_THAN_NORMAL_SIZE | shape: (1280,)
# 🔹 Processing sign: DRY_YOUR_FEET_PROPERLY_AFTER_TAKING_A_BATH
# ✅ Saved embedding for DRY_YOUR_FEET_PROPERLY_AFTER_TAKING_A_BATH | shape: (1280,)
# 🔹 Processing sign: EID
# ✅ Saved embedding for EID | shape: (1280,)
# 🔹 Processing sign: HOW
# ✅ Saved embedding for HOW | shape: (1280,)
# 🔹 Processing sign: IT_IS_FINE
# ✅ Saved embedding for IT_IS_FINE | shape: (1280,)
# 🔹 Processing sign: IT_S_UP_TO_YOU
# ✅ Saved embedding for IT_S_UP_TO_YOU | shape: (1280,)
# 🔹 Processing sign: STAY_HERE_TODAY
# ✅ Saved embedding for STAY_HERE_TODAY | shape: (1280,)
# 🔹 Processing sign: WHAT_IS_YOUR_E_MAIL_ADDRESS
# ✅ Saved embedding for WHAT_IS_YOUR_E_MAIL_ADDRESS | shape: (1280,)
# 🔹 Processing sign: YOUR_LANGUAGE
# ✅ Saved embedding for YOUR_LANGUAGE | shape: (1280,)
